# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
# Loading the data
raw_data = pd.read_csv('.\static\data\RedWhiteWines.csv')
raw_data.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# ...

# %%
raw_data.describe(include='all')
# Out:
#         fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count     6497.000000       6497.000000  6497.000000     6497.000000
# unique            NaN               NaN          NaN             NaN
# top               NaN               NaN          NaN             NaN
# freq              NaN               NaN          NaN             NaN
# mean         7.215307          0.339666     0.318633        5.443235
# std          1.296434          0.164636     0.145318        4.757804
# min          3.800000          0.080000     0.000000        0.600000
# 25%          6.400000          0.230000     0.250000        1.800000
# 50%          7.000000          0.290000     0.310000        3.000000
# 75%          7.700000          0.400000     0.390000        8.100000
# max         15.900000          1.580000     1.660000       65.800000
#
#           chlorides  free.sulfur.dioxide  total.sulfur.dioxide      density  \
# ...

# %%
raw_data.isnull()
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# 5             False             False        False           False      False
# 6             False             False        False           False      False
# 7             False             False        False           False      False
# 8             False             False        False           False      False
# 9             False             False        False           False      False
# 10            False             False        False           False      False
# ...

# %%
data = raw_data.copy()
data['type'] = data['type'].map({'red':0, 'white':1})
data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# ...

# %%
# Define dependend and independent variables
y = data['quality']
x1 = data[['alcohol','type']]

# %%
# Explore the data
#plt.scatter(x1,y)
#plt.xlabel('alcohol',fontsize=20)
#plt.ylabel('quality',fontsize=20)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-6b5108896552> in <module>
#       1 # Explore the data
# ----> 2 plt.scatter(x1,y)
#       3 plt.xlabel('alcohol',fontsize=20)
#       4 plt.ylabel('quality',fontsize=20)
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# ...

# %%
# Simple Linear Regression using Ordinary Least Squares (OLS) model
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     854.8
# Date:                Sat, 08 Feb 2020   Prob (F-statistic):               0.00
# Time:                        11:42:56   Log-Likelihood:                -7578.7
# No. Observations:                6497   AIC:                         1.516e+04
# Df Residuals:                    6494   BIC:                         1.518e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2717      0.087     26.258      0.000       2.102       2.441
# ...

# %%
# Using data from the coefficient table 
# Plot the regression line (predicted variables based on data)
plt.scatter(data['alcohol'],y)
#yhat = 0.3608*x1 + 1.8750
yhat_red = *data['alcohol'] + 2.2717
yhat_white = *data['alcohol'] 
fig = plt.plot(x1,yhat,lw=4,c='orange',label='regression line')
plt.xlabel('alcohol',fontsize=20)
plt.ylabel('quality',fontsize=20)
plt.show()

# %%
# Making predictions using StatsModels method
new_data = pd.DataFrame({'const':1,'alcohol':[5,10]})
new_data = new_data[['const','alcohol']]
predictions = results.predict(new_data)

# Transform into dataframe and join it with the first one
predictionsDf = pd.DataFrame({'Predicted_Quality':predictions})
joined = new_data.join(predictionsDf)
joined
# Out:
#    const  alcohol  Predicted_Quality
# 0      1        5           3.679184
# 1      1       10           5.483393
